# %%
import numpy as np                  # Mathetimatical Operations
import pandas as pd                 # Data manipulation

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt     
# %matplotlib inline

# Sklearn
from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, auc, roc_curve, roc_auc_score, classification_report, mean_squared_error, confusion_matrix, f1_score, precision_recall_curve, r2_score 
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.ensemble import AdaBoostRegressor, BaggingRegressor, GradientBoostingRegressor, RandomForestRegressor

# Scipy
from scipy.stats import stats
from scipy.stats import ttest_ind, ttest_ind_from_stats

# XGBoost
from xgboost import XGBClassifier
from xgboost import XGBRegressor
import xgboost as xgb

# Datetime
import datetime 
import time
from datetime import datetime

# Folium
import folium 
from folium import plugins
from folium.plugins import HeatMap

# Image
from IPython.display import Image

# Bayesian Optimizer
from skopt import BayesSearchCV

# Itertools
import itertools

# Remove warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df_info = pd.read_csv('account_info.csv')
df_labels = pd.read_csv('account_labels.csv')

# %%
df_info.head()
# Out:
#                                          account_id              category  \
# 0  a21sanZjcHRlbGl8f2ZoZXJ2ZWx4a3pmdmh9aHp2emttbmVi  ATM/Cash Withdrawals
# 1  a21sanZjcHRlbGl8f2ZoZXJ2ZWx4a3pmdmh9aHp2emttbmVi                Checks
# 2  a21sanZjcHRlbGl8f2ZoZXJ2ZWx4a3pmdmh9aHp2emttbmVi         Gasoline/Fuel
# 3  a21sanZjcHRlbGl8f2ZoZXJ2ZWx4a3pmdmh9aHp2emttbmVi             Groceries
# 4  a21sanZjcHRlbGl8f2ZoZXJ2ZWx4a3pmdmh9aHp2emttbmVi             Mortgages
#
#     balance  debits  credits
# 0   -100.00       1        0
# 1 -39182.84      39        0
# 2      0.00       0        0
# 3      0.00       0        0
# 4      0.00       0        0

# %%
df_labels.head()
# Out:
#                                          account_id  label
# 0  anl7fnp2cHVlentxfWZoYW93ZWxncW5mZnZtZXpobmpxbnV1      1
# 1  aHxwaW10fmhldn1xamZoam5zZWxwcXtmZHV-anx2bnBpbXl2      1
# 2  em1ycHZyfWZlaHtpfGZoaX5mZW18a2tmZ3ZpZXFlbnF7cGdm      0
# 3  en5pb2d2cXVlZ3t9e2ZoYXt0ZXV9bHFmaGZ8YmltbGt8b2Vq      0
# 4  cHp8amh0amJldmloe2ZocntkZWx9cH5maXJsYmhlenFqb2xy      1

# %%
df = df_info.merge(df_labels)

# %%
df.head(20)
# Out:
#                                           account_id              category  \
# 0   a21sanZjcHRlbGl8f2ZoZXJ2ZWx4a3pmdmh9aHp2emttbmVi  ATM/Cash Withdrawals
# 1   a21sanZjcHRlbGl8f2ZoZXJ2ZWx4a3pmdmh9aHp2emttbmVi                Checks
# 2   a21sanZjcHRlbGl8f2ZoZXJ2ZWx4a3pmdmh9aHp2emttbmVi         Gasoline/Fuel
# 3   a21sanZjcHRlbGl8f2ZoZXJ2ZWx4a3pmdmh9aHp2emttbmVi             Groceries
# 4   a21sanZjcHRlbGl8f2ZoZXJ2ZWx4a3pmdmh9aHp2emttbmVi             Mortgages
# 5   a21sanZjcHRlbGl8f2ZoZXJ2ZWx4a3pmdmh9aHp2emttbmVi    Restaurants/Dining
# 6   a21sanZjcHRlbGl8f2ZoZXJ2ZWx4a3pmdmh9aHp2emttbmVi                 Sales
# 7   a21sanZjcHRlbGl8f2ZoZXJ2ZWx4a3pmdmh9aHp2emttbmVi                 Taxes
# 8   a21sanZjcHRlbGl8f2ZoZXJ2ZWx4a3pmdmh9aHp2emttbmVi            Wages Paid
# 9   a21sanZjcHRlbGl8f2ZoZXJ2ZWx4a3pmdmh9aHp2emttbmVi               Overall
# 10  a21vf2h0fWZlanttfGZocn9pZWxwcXBmZXNrd21panl_f2hn  ATM/Cash Withdrawals
# 11  a21vf2h0fWZlanttfGZocn9pZWxwcXBmZXNrd21panl_f2hn                Checks
# 12  a21vf2h0fWZlanttfGZocn9pZWxwcXBmZXNrd21panl_f2hn         Gasoline/Fuel
# 13  a21vf2h0fWZlanttfGZocn9pZWxwcXBmZXNrd21panl_f2hn             Groceries
# 14  a21vf2h0fWZlanttfGZocn9pZWxwcXBmZXNrd21panl_f2hn             Mortgages
# 15  a21vf2h0fWZlanttfGZocn9pZWxwcXBmZXNrd21panl_f2hn    Restaurants/Dining
# 16  a21vf2h0fWZlanttfGZocn9pZWxwcXBmZXNrd21panl_f2hn                 Sales
# 17  a21vf2h0fWZlanttfGZocn9pZWxwcXBmZXNrd21panl_f2hn                 Taxes
# 18  a21vf2h0fWZlanttfGZocn9pZWxwcXBmZXNrd21panl_f2hn            Wages Paid
# 19  a21vf2h0fWZlanttfGZocn9pZWxwcXBmZXNrd21panl_f2hn               Overall
#
#      balance  debits  credits  label
# 0    -100.00       1        0      0
# 1  -39182.84      39        0      0
# 2       0.00       0        0      0
# 3       0.00       0        0      0
# 4       0.00       0        0      0
# 5     -26.36       1        0      0
# 6       0.00       0        0      0
# 7   -6907.52       1        0      0
# 8       0.00       0        0      0
# 9   11574.41     240      192      0
# 10  -5239.95      25        0      0
# 11 -28641.09      25        0      0
# 12   -512.19      13        0      0
# 13      0.00       0        0      0
# 14      0.00       0        0      0
# 15    -20.64       1        0      0
# 16      0.00       0        0      0
# 17      0.00       0        0      0
# 18      0.00       0        0      0
# 19  22634.59     328      200      0

# %%
df['label'].value_counts()
# Out:
# 0    8520
# 1    1480
# Name: label, dtype: int64

# %%
df[df['label']==1].head(20)
# Out:
#                                            account_id              category  \
# 20   a21xbnpzfWdlbHl7fWZod3BlZW1tbXBmenNqYXtqfGxtaXhq  ATM/Cash Withdrawals
# 21   a21xbnpzfWdlbHl7fWZod3BlZW1tbXBmenNqYXtqfGxtaXhq                Checks
# 22   a21xbnpzfWdlbHl7fWZod3BlZW1tbXBmenNqYXtqfGxtaXhq         Gasoline/Fuel
# 23   a21xbnpzfWdlbHl7fWZod3BlZW1tbXBmenNqYXtqfGxtaXhq             Groceries
# 24   a21xbnpzfWdlbHl7fWZod3BlZW1tbXBmenNqYXtqfGxtaXhq             Mortgages
# 25   a21xbnpzfWdlbHl7fWZod3BlZW1tbXBmenNqYXtqfGxtaXhq    Restaurants/Dining
# 26   a21xbnpzfWdlbHl7fWZod3BlZW1tbXBmenNqYXtqfGxtaXhq                 Sales
# 27   a21xbnpzfWdlbHl7fWZod3BlZW1tbXBmenNqYXtqfGxtaXhq                 Taxes
# 28   a21xbnpzfWdlbHl7fWZod3BlZW1tbXBmenNqYXtqfGxtaXhq            Wages Paid
# 29   a21xbnpzfWdlbHl7fWZod3BlZW1tbXBmenNqYXtqfGxtaXhq               Overall
# 190  a2puamt1bnRlZGhtfWZoZ3x1ZXV9aHtmdWlxZnBncG97a2pq  ATM/Cash Withdrawals
# 191  a2puamt1bnRlZGhtfWZoZ3x1ZXV9aHtmdWlxZnBncG97a2pq                Checks
# 192  a2puamt1bnRlZGhtfWZoZ3x1ZXV9aHtmdWlxZnBncG97a2pq         Gasoline/Fuel
# 193  a2puamt1bnRlZGhtfWZoZ3x1ZXV9aHtmdWlxZnBncG97a2pq             Groceries
# 194  a2puamt1bnRlZGhtfWZoZ3x1ZXV9aHtmdWlxZnBncG97a2pq             Mortgages
# 195  a2puamt1bnRlZGhtfWZoZ3x1ZXV9aHtmdWlxZnBncG97a2pq    Restaurants/Dining
# 196  a2puamt1bnRlZGhtfWZoZ3x1ZXV9aHtmdWlxZnBncG97a2pq                 Sales
# 197  a2puamt1bnRlZGhtfWZoZ3x1ZXV9aHtmdWlxZnBncG97a2pq                 Taxes
# 198  a2puamt1bnRlZGhtfWZoZ3x1ZXV9aHtmdWlxZnBncG97a2pq            Wages Paid
# 199  a2puamt1bnRlZGhtfWZoZ3x1ZXV9aHtmdWlxZnBncG97a2pq               Overall
#
#       balance  debits  credits  label
# 20   -1004.95       3        0      1
# 21  -27028.16      70        0      1
# 22    -852.70      19        0      1
# 23    -145.09       3        0      1
# 24       0.00       0        0      1
# 25    -246.43       9        0      1
# 26       0.00       0        0      1
# 27    -249.93       2        0      1
# 28       0.00       0        0      1
# 29    7225.57     374       36      1
# 190    -22.50       1        0      1
# 191  -6288.79       6        0      1
# 192   -119.27       4        0      1
# 193   -662.27       4        0      1
# 194      0.00       0        0      1
# 195    -28.12       1        0      1
# 196      0.00       0        0      1
# 197      0.00       0        0      1
# 198      0.00       0        0      1
# 199   6494.54      82       11      1
